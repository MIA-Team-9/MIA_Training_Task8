# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 617.0/617.0 kB 7.1 MB/s eta 0:00:00
# ...

# %%
# %cd /content/drive/MyDrive/Model
# Out:
# /content/drive/MyDrive/Model

# %%
# !yolo task=detect mode=train data=/content/po.yaml epochs=100 imgsz=640
# Out:
# Ultralytics YOLOv8.0.180 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
from ultralytics import YOLO
model = YOLO(r"/content/drive/MyDrive/Model/runs/detect/train2/weights/best.pt")

# %%
model.train(data="/content/po.yaml", epochs=100, imgsz=640)
# Out:
# Ultralytics YOLOv8.0.180 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...
